# %% [markdown]
#  # 1. Check Whether a Number is Positive, Negative, or Zero

# %%
num=int(input())
if num>0:
    print("postive number")
elif num<0:
    print("negative number")
else:
    print("zero")
# Out:
#  120
# postive number

# %% [markdown]
# # 2. Check Whether a Number is Even or Odd

# %%
num=int(input())
if num%2==0:
    print("even number")
else:
    print("odd number")
# Out:
#  2
# even number

# %% [markdown]
#  # 3. Check Whether a Number is Divisible by 5 and 11

# %%
num=int(input())
if num%5==0 and num%11==0:
    print("divisible by both 5 and 11")
else:
    print("not divisible by 5 and 11")
# Out:
#  30
# not divisible by 5 and 11

# %% [markdown]
# # 4. Check Whether a Character is Uppercase or Lowercase

# %%
ch=input("enter a character")
if ch.isupper():
    print("upper case character:",ch)
elif ch.islower():
    print("lower case character:",ch)
else:
    print("not an alphabet")
# Out:
# enter a character 123
# not an alphabet

# %% [markdown]
# # 5. Check Whether a Character is a Vowel or Consonant

# %%
ch=input("enter a character")
if ch in "AEIOUaeiou":
    print("character is a vowel")
else:
    print("character is consonant")
# Out:
# enter a character q
# character is consonant

# %% [markdown]
# # 6. Check Whether a Character is an Alphabet, Digit, or Special Character

# %%
ch=input()
if ch.isalpha():
    print("alphabet")
elif ch.isdigit():
    print("digit")
else:
    print("speacialcharacters")
# Out:
#  @
# speacialcharacters

# %% [markdown]
#  # 7. Find the Largest of Three Numbers

# %%
a=int(input())
b=int(input())
c=int(input())
if a>b and a>c:
    print("largest is:",a)
elif b>a and b>c:
    print("largest is:",b)
else:
    print("largest is:",c)
# Out:
#  10
#  20
#  30
# largest is: 30

# %% [markdown]
#  # 8. Find the Greatest Among Four Numbers

# %%
a=int(input())
b=int(input())
c=int(input())
d=int(input())
if a>b and a>c and a>d:
    print("largest is:",a)
elif b>a and b>c and b>d:
    print("largest is:",b)
elif c>a and c>b and c>d:
    print("largest is:",c)
else:
    print("largest is:",d)
# Out:
#  10
#  20
#  30
#  40
# largest is: 40

# %% [markdown]
#  # 9. Check Whether Three Angles Form a Valid Triangle

# %%
a=int(input("First side angle:"))
b=int(input("Second side angle:"))
c=int(input("Third side angle:"))
if a>0 and b>0 and c>0 and a+b+c==180:
    print("valid triangle")
else:
    print("Invalid triangle")
# Out:
# First side angle: 60
# Second side angle: 60
# Third side angle: 60
# valid triangle

# %% [markdown]
#  # 10. Determine the Type of Triangle from Three Sides

# %%
a=int(input("First side angle:"))
b=int(input("Second side angle:"))
c=int(input("Third side angle:"))
if a==b and b==c:
    print("Equilateral triangle")
elif a==b or b==c or a==c:
    print("isosciles triangle")
else:
    print("scalene traiangle")
# Out:
# First side angle: 60
# Second side angle: 60
# Third side angle: 30
# isosciles triangle

# %% [markdown]
#  # 11. Check Whether a Year is a Leap Year

# %%
year=int(input())
if year%400==0 or (year%4==0 and year%100!=0):
    print("Leap year")
else:
    print("Not a leap year")
# Out:
#  2000
# Leap year

# %% [markdown]
#  # 12. Check Whether a Student is Pass or Fail

# %%
marks=int(input())
if marks>=40:
    print("passed")
else:
    print("fail")
# Out:
#  60
# passed

# %% [markdown]
#  # 14. Find the Roots of a Quadratic Equation

# %%
import math

a = float(input("Enter a: "))
b = float(input("Enter b: "))
c = float(input("Enter c: "))

d = b * b - 4 * a * c

if d > 0:
    root1 = (-b + math.sqrt(d)) / (2 * a)
    root2 = (-b - math.sqrt(d)) / (2 * a)
    print("Root 1 =", root1)
    print("Root 2 =", root2)

elif d == 0:
    root = -b / (2 * a)
    print("Both roots are =", root)

else:
    print("No real roots")
# Out:
# Enter a:  20
# Enter b:  40
# Enter c:  6
# Root 1 = -0.16333997346592444
# Root 2 = -1.8366600265340758

# %% [markdown]
#  # 15. Shopping Bill Calculator with Discount Slabs

# %%
amount=int(input())
if amount>=5000:
    discount=amount*20/100
elif amount>=1000:
    discount=amount*10/100
else:
    discount=0
final_amount=amount-discount    
    
print("discount:",discount)
print("Bill genearation:",final_amount)
# Out:
#  4095
# discount: 409.5
# Bill genearation: 3685.5

# %% [markdown]
#  # 16. Electricity Bill Calculator Using Slab Rates

# %%
units = int(input("Enter electricity units: "))

if units <= 100:
    bill = units * 2
elif units <= 200:
    bill = (100 * 2) + ((units - 100) * 3)
else:
    bill = (100 * 2) + (100 * 3) + ((units - 200) * 5)

print("Electricity Bill =", bill)
# Out:
# Enter electricity units:  300
# Electricity Bill = 1000

# %% [markdown]
#  # 17. Income Tax Calculator Using Tax Slabs

# %%
income=int(input())
if income<=250000:
    tax=0
elif income<=5000000:
    tax=income*5/100
else:
    tax=income*20/100
print("tax:",tax)
# Out:
#  300000
# tax: 15000.0

# %% [markdown]
#  # 18. Calculate Bonus Based on Employee Experience

# %%
salary = float(input("Enter salary: "))
experience = int(input("Enter experience in years: "))

if experience < 2:
    bonus = 0
elif experience <= 5:
    bonus = salary * 10 / 100
elif experience <= 10:
    bonus = salary * 20 / 100
else:
    bonus = salary * 30 / 100

print("Bonus =", bonus)
# Out:
# Enter salary:  20000
# Enter experience in years:  10
# Bonus = 4000.0

# %% [markdown]
#  # 19. ATM Cash Withdrawal with Minimum Balance Check

# %%
balance=float(input("Enter account balance:"))
withdraw_amount=float(input("Enter withdraw amount:"))
if withdraw_amount<=0:
    print("Invalid with draw amount entered")
elif withdraw_amount>balance:
    print("insuuficent balance")
elif balance-withdraw_amount<1000:
    print("Minimum balance of 1000 should be maintened")
else:
    balance=balance-withdraw_amount
    print("withdraw successfull")
    print("Remaining balance:",balance)
# Out:
# Enter account balance: 5000
# Enter withdraw amount: 3000
# withdraw successfull
# Remaining balance: 2000.0

# %% [markdown]
#  # 20. Simple Calculator Using if-elif-else

# %%
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
operator = input("Enter operator (+, -, *, /): ")

if operator == "+":
    print("Result =", a + b)

elif operator == "-":
    print("Result =", a - b)

elif operator == "*":
    print("Result =", a * b)

elif operator == "/":
    if b != 0:
        print("Result =", a / b)
    else:
        print("Cannot divide by zero")

else:
    print("Invalid Operator")
