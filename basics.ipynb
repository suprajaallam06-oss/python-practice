# %% [markdown]
# # DATA TYPES

# %%
# Type of a value is known as data type
# In python we are not required specify the type explicity.based on the values it is assinged automatically
# python is dynamically typed language
a=10
print(type(a))
# Out:
# <class 'int'>

# %%
b=10.0
print(type(b))
# Out:
# <class 'float'>

# %%
c="shiva"
print(type(c))
# Out:
# <class 'str'>

# %%
c=False
print(type(c))
# Out:
# <class 'bool'>

# %%
e=2+5j
print(type(e))
# Out:
# <class 'complex'>

# %% [markdown]
# # INPUT FUNCTIONS:

# %% [markdown]
# ## Form 1-Input function without prompt

# %%
name=input()
print("name:",name)
# Out:
#  shiva
# name: shiva

# %% [markdown]
# ## Form 2-input function with prompt

# %%
name=input("enter your name")
# Out:
# enter your name shiva

# %% [markdown]
# ## Form 3- Input function with conversion

# %%
name=input("enter student name:")
rollno=int(input("enter age:"))
marks=float(input("enter marks:"))
# Out:
# enter student name: shiva
# enter age: 20
# enter marks: 9.2

# %% [markdown]
# ## Form 4-Input Function with split()

# %%
a,b,c=input().split()
print(a)
print(b)
print(c)
# Out:
#  10 20 30
# 10
# 20
# 30

# %% [markdown]
# ## Form 5-Input function with map()

# %%
a,b,c=map(int,input().split())
print(a)
print(b)
print(c)
print(a+b+c)
# Out:
#  10 20 30
# 10
# 20
# 30
# 60

# %% [markdown]
# ## Form 6-Reading a single character

# %%
ch=inp
